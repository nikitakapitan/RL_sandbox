# %%
# %%capture
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb

# !pip install pygame # UI for gym envs

# !pip install huggingface_hub
# !pip install pickle5
# !pip install imageio imageio_ffmpeg

# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

import numpy as np
import gym
import random
import imageio
import os

import pickle5 as pickle

# %%
# !pip install pyyaml==6.0 # avoid key error metadata
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyyaml==6.0 in /usr/local/lib/python3.7/dist-packages (6.0)

# %%
env = gym.make("FrozenLake-v0", map_name="4x4", is_slippery=False)
env.reset()

qstates = env.observation_space.n
qactions = env.action_space.n

# Q-table
qtable = [[0]*qactions]*qstates

# %%
def greedy_policy(qtable, state, eps_greedy=False, epsilon=0.01):
  if eps_greedy:
    rand = np.random.rand()
    if rand < epsilon:
      return env.action_space.sample()
  return np.argmax(qtable[state])

# %%
#Hyperparameters:
n_training_episodes = 10_000
Learning_rate = 0.7
n_eval_episodes = 100
env_id = "FrozenLake-v0"
max_steps = 99                # max steps by agent per episode
gamma = 0.99                  # reward discount rate

# exploration decay
epsilon = 1.0
min_eps = 0.05
decay_rate = 0.000_5

# %%
def train(env, max_steps, qtable, n_training_episodes, min_eps, decay_rate):

  for _ in range(n_training_episodes):
    state = (0,0)
    step = 1
    epsilon = 1.0
    for step in range(max_steps):
      action = greedy_policy(qtable, state, eps_greedy=True, epsilon=epsilon)
      new_state, reward, done, info = env.step(action)
      qtable[state][action] += Learning_rate * (reawrd - )

      state = new_state
      epsilon = max(min_eps, epsilon - decay_rate)
